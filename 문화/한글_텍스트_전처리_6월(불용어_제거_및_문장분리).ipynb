# %%
#- 패키지 임포트
import pandas as pd
import numpy as np
#import emoji # 이모지 제거용
import re
from soynlp.normalizer import * #반복되는 자음 제거
import time
from tqdm.notebook import tqdm #for문 진행률 
from time import sleep #for문 진행 시간 
from kiwipiepy import Kiwi #문장 분리2

from IPython.display import clear_output
from IPython import display # 램효율을 늘리기 위해 아웃풋 display를 지워줄 것.
from ipywidgets import Output

out = Output()
display.display(out)
# Out:
# Output()

# %%
''' 파일 불러오기 '''
df = pd.read_csv("./나무문화/2022/나무문화_본문_2022_6월.csv", encoding='UTF-8')
# print(df.shape, type(df)) # 파일 구조 및 컬럼명 확인용
df['org_idx']= df.index # 인덱스 column 만들기: 문장 분리할 때 사용함
# print(df.columns) # org_idx 제대로 추가됐나 단순 확인용.
post_list = list(df['본문']) #자연어 전처리를 위해 본문을 리스트 형태로

# %%
''' 불용어 제거 '''
# post_list 양이 많을 경우 불용어 제거 중에 오류 나면 다시 리스트로 만드는 데 오래 걸려서 카피하는 것임. 안 하고 post_list로 진행해도 됨.
post_list2 = post_list.copy()
for i in range(len(post_list2)):
    post_list2[i] = re.sub('\n', ' ', string=str(post_list2[i])) # 줄바꿈을 띄어쓰기 하나로
    post_list2[i] = re.compile('[^|ㄱ-ㅎ|ㅏ-ㅣ|A-Z|a-z|0-9|가-힣]+').sub(' ',post_list2[i])
    post_list2[i] = repeat_normalize(post_list2[i], num_repeats=1)
	# ↑ ㅋㅋㅋ, ㅎㅎㅎ 등의 의미 없는 자음 삭제. num_repeats가 1이면 반복 글자 중 1개만 남기고 2면 2개만 남김.
    post_list2[i] = re.sub(r"^\s+|\s+$", "", post_list2[i]) # 문서 앞뒤 공백 제거
    post_list2[i] = post_list2[i].split() # 문서 내 공백(1개 이상) 기준으로 자르기
    post_list2[i] = ' '.join(post_list2[i]) # 공백 기준으로 나뉜 문서를 다시 1개의 공백을 두고 붙임.
	# ↑ 문서 내 다중 공백을 지우기 위함.]

df['cleaning'] = pd.DataFrame(post_list2) #불용어 제거된 본문을 데이터 프레임으로

# %%
df
# Out:
#                                                      url  \
# 0          https://blog.naver.com/ccalvados/222795576909
# 1         https://blog.naver.com/stepan5844/222795577522
# 2        https://blog.naver.com/i_ipossible/222795577237
# 3          https://blog.naver.com/hyhan2028/222795577392
# 4          https://blog.naver.com/charnnant/222795577621
# ...                                                  ...
# 11962      https://blog.naver.com/hsook0417/222754273924
# 11963  https://blog.naver.com/flower_daltuium/2227542...
# 11964     https://blog.naver.com/sohee10723/222754236890
# 11965       https://blog.naver.com/poyang84/222754272099
# 11966        https://blog.naver.com/sheshow/222699446696
#
#                                                       본문  org_idx  \
# 0      7월 개봉 예정 영화, 신작 영화추천\n신작 영화 추천! 극장 개봉 예정 영화 7월...        0
# 1      6월 20일\n지인이 파니를 위해\n카메라를 닦고 닦고 또 닦아\n완전 새거처럼 만...        1
# 2      2박 3일 파주여행을 하고 온 담담!\n이번 여행은 혼자 떠나기도했고\n요즘 바쁘다...        2
# 3      안녕하세요 연쓰입니다. 오늘은 좀 특별한 이색카페를 다녀왔어요.\n연쓰는 평소에 집...        3
# 4      ⏰ 9:30 ~ 18:00\n🚘 주차 가능\n안녕하세요! 챠넷입니다 :D\n장마가 ...        4
# ...                                                  ...      ...
# 11962  #신영복 평전\n1. 책소개\n75년, 신영복의 삶을 정리하다!\n돌아간 지 4년이...    11962
# 11963  안녕하세요 #달꽃틔움숲 이에요\n현재 달꽃틔움숲에서는 다양한 커리큘럼의 클래스를 모...    11963
# 11964  춘천여행\n레고랜드, 남이섬 말고\n여기어때~??\n강원도 춘천시 신동면 김유정로 ...    11964
# 11965  오늘의 답사 코스\n열세 번째 유네스코 세계유산 '한국의 산사' 영주 부석사를 답사...    11965
# 11966  blog\n인류의위대한여행 55개의 글\n인류의위대한여행\n목록닫기\n인류의위대한여...    11966
#
#                                                 cleaning
# 0      7월 개봉 예정 영화 신작 영화추천 신작 영화 추천 극장 개봉 예정 영화 7월 리부...
# 1      6월 20일 지인이 파니를 위해 카메라를 닦고 닦고 또 닦아 완전 새거처럼 만들어 ...
# 2      2박 3일 파주여행을 하고 온 담담 이번 여행은 혼자 떠나기도했고 요즘 바쁘다는 핑...
# 3      안녕하세요 연쓰입니다 오늘은 좀 특별한 이색카페를 다녀왔어요 연쓰는 평소에 집에서 ...
# 4      9 30 18 00 주차 가능 안녕하세요 챠넷입니다 D 장마가 시작되면서 비가 정말...
# ...                                                  ...
# 11962  신영복 평전 1 책소개 75년 신영복의 삶을 정리하다 돌아간 지 4년이 흘렀지만 여...
# 11963  안녕하세요 달꽃틔움숲 이에요 현재 달꽃틔움숲에서는 다양한 커리큘럼의 클래스를 모집 ...
# 11964  춘천여행 레고랜드 남이섬 말고 여기어때 강원도 춘천시 신동면 김유정로 1435 첫번...
# 11965  오늘의 답사 코스 열세 번째 유네스코 세계유산 한국의 산사 영주 부석사를 답사하러 ...
# 11966  blog 인류의위대한여행 55개의 글 인류의위대한여행 목록닫기 인류의위대한여행 글 ...
#
# [11967 rows x 4 columns]

# %%
''' 문장 분리 '''
kiwi = Kiwi() #kss보다 속도 빠름 
split_list = [kiwi.split_into_sents(df['cleaning'][i]) for i in tqdm(range(len(df['cleaning'])))]
df['split_list'] = split_list
df
# Out:
#   0%|          | 0/11967 [00:00<?, ?it/s]
#                                                      url  \
# 0          https://blog.naver.com/ccalvados/222795576909
# 1         https://blog.naver.com/stepan5844/222795577522
# 2        https://blog.naver.com/i_ipossible/222795577237
# 3          https://blog.naver.com/hyhan2028/222795577392
# 4          https://blog.naver.com/charnnant/222795577621
# 1      [(6월 20일 지인이 파니를 위해 카메라를 닦고 닦고 또 닦아 완전 새거처럼 만들...
# 2      [(2박 3일 파주여행을 하고 온 담담 이번 여행은 혼자 떠나기도했고 요즘 바쁘다는...
# 3      [(안녕하세요 연쓰입니다, 0, 11, None, []), (오늘은 좀 특별한 이색...
# 4      [(9 30 18 00 주차 가능 안녕하세요 챠넷입니다, 0, 28, None, [...
# ...                                                  ...
# 11962  [(신영복 평전 1 책소개 75년 신영복의 삶을 정리하다 돌아간 지 4년이 흘렀지만...
# 11963  [(안녕하세요 달꽃틔움숲 이에요, 0, 15, None, []), (현재 달꽃틔움숲...
# 11964  [(춘천여행 레고랜드 남이섬 말고 여기어때, 0, 21, None, []), (강원...
# 11965  [(오늘의 답사 코스 열세 번째 유네스코 세계유산 한국의 산사 영주 부석사를 답사하...
# 11966  [(blog 인류의위대한여행 55개의 글 인류의위대한여행 목록닫기 인류의위대한여행 ...
#
# [11967 rows x 5 columns]

# %%
# 데이터프레임을 1000개 단위로 나누기
chunk_size = 1000
num_chunks = len(df) // chunk_size + 1  # 나머지가 있는 경우 추가적인 청크 필요

dfs = {}
for i in range(num_chunks):
    start_idx = i * chunk_size
    end_idx = (i + 1) * chunk_size
    chunk_df = df[start_idx:end_idx]
    dfs[f"df_{i+1}"] = chunk_df

# 생성된 데이터프레임들 확인
for key, chunk_df in dfs.items():
    print(key)
# Out:
# df_1
# df_2
# df_3
# df_4
# df_5
# df_6
# df_7
# df_8
# df_9
# df_10
# df_11
# df_12

# %%
# ''' 분리된 문장 한 개를 한 row로 '''
# df2 = pd.DataFrame(columns = ['split_str', 'org_idx']) #용량을 줄이기 위해 새로운 데이터프레임으로

# ''' 문장 데이터 프레임 저장 '''
# df2.to_csv("./나무문화/2022/나무문화_본문_6월_전처리.csv", index=False, encoding='UTF-8')

# %%
df2 = pd.read_csv("./나무문화/2022/나무문화_본문_6월_전처리.csv", encoding='UTF-8')
df2
# Out:
# Empty DataFrame
# Columns: [split_str, org_idx]
# Index: []

# %%
dfs['df_1']['split_list'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
for a in range(1,len(dfs)+1):
    for i in tqdm(dfs['df_%s'%a]['split_list'].index):
        for j in range(len(dfs['df_%s'%a]['split_list'][i])):
            split_str= {'split_str': dfs['df_%s'%a]['split_list'][i][j][0], 'org_idx': [i]}
            print(split_str['org_idx'])
            split_df= pd.DataFrame(split_str)
            df2 = pd.concat([df2,split_df])
            df2.reset_index(drop=True, inplace=True)
            display.clear_output(wait=True) # 출력지우기
        else:
            time.sleep(1)
df2.reset_index(drop=True, inplace=True)
df2

# %%
df2.to_csv("./나무문화/2022/나무문화_본문_6월_전처리.csv", index=False, encoding='UTF-8')
